# %% [markdown]
# <img src="https://raw.githubusercontent.com/hyegyu/VC24220/main/%EC%A0%9C%EB%AA%A9.jpg"></img>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/hyegyu/VC24220/main/1%EC%B0%A8%EB%B3%80%EA%B2%BD%EC%82%AC%ED%95%AD.jpg"></img>
# 데이터출처 : https://github.com/choosunsick/Korea_Stocks.git

# %% [markdown]
# ### 데이터 불러오기

# %%
import os
path='C:/Users/yhg31/OneDrive/바탕 화면/Korea_Stocks-master/Korea_Stocks-master/Korea_Stocks_Full'
forders= os.listdir(path)
len(forders)
# Out:
# 200

# %%
forders[0:5]
# Out:
# ['000070.csv', '000080.csv', '000100.csv', '000120.csv', '000150.csv']

# %%
import pandas as pd
df = pd.DataFrame()

for i in range(200): 
    link=path+"/"+forders[i]
    dfdf= pd.read_csv(link) 
    dfdf["name"]=forders[i].split(".csv")[0]
    df = pd.concat([df, dfdf])

# %%
df
# Out:
#            Date   Open   High    Low  Close    Volume  Adj_Close    name
# 0    2005-09-29  43517  45553  43466      0     49472      36129  000070
# 1    2005-09-30  45808  47436  45604      0     72960      37515  000070
# 2    2005-10-04  47742  47742  46011      0     25256      37393  000070
# 3    2005-10-05  46927  47131  44841      0     36053      35925  000070
# 4    2005-10-06  44383  44993  43110      0     38066      34987  000070
# ..          ...    ...    ...    ...    ...       ...        ...     ...
# 531  2021-04-09  10500  10500  10200  10300  19929467      10300  316140
# 532  2021-04-12  10300  10450  10250  10400   2507164      10400  316140
# 533  2021-04-13  10450  10450  10300  10350   2085798      10350  316140
# 534  2021-04-14  10350  10400  10300  10400   1503857      10400  316140
# 535  2021-04-15  10400  10550  10350  10400   2454194      10400  316140
#
# [832352 rows x 8 columns]

# %%
#분석 시 대문자는 치기 힘들어서 소문자로 변경
df=df.rename(columns={'Date':'date', 'Open':'open', 'High':'high', 'Low':'low', 'Close':'close', 'Volume':'volume', 'Adj_Close':'adj_close'})
df=df.reset_index(drop=True)
df
# Out:
#               date   open   high    low  close    volume  adj_close    name
# 0       2005-09-29  43517  45553  43466      0     49472      36129  000070
# 1       2005-09-30  45808  47436  45604      0     72960      37515  000070
# 2       2005-10-04  47742  47742  46011      0     25256      37393  000070
# 3       2005-10-05  46927  47131  44841      0     36053      35925  000070
# 4       2005-10-06  44383  44993  43110      0     38066      34987  000070
# ...            ...    ...    ...    ...    ...       ...        ...     ...
# 832347  2021-04-09  10500  10500  10200  10300  19929467      10300  316140
# 832348  2021-04-12  10300  10450  10250  10400   2507164      10400  316140
# 832349  2021-04-13  10450  10450  10300  10350   2085798      10350  316140
# 832350  2021-04-14  10350  10400  10300  10400   1503857      10400  316140
# 832351  2021-04-15  10400  10550  10350  10400   2454194      10400  316140
#
# [832352 rows x 8 columns]

# %% [markdown]
# #### 데이터 설명
#
# 속성명|뜻|활용
# ---|---|---
# date|해당 데이터 날짜|년/월/일/요일 분리 예정
# open|시작한 가격(시가)|시가와 종가의 차이
# high|최고 가격|최고가와 최저가의 중간값(평균)
# low|최저 가격|최고가와 최저가의 중간값(평균)
# close|종료시 가격(종가)|시가와 종가의 차이
# volume|거래량
# adj_close|수정주가(분할, 배당, 배분, 신주 발생이 된 경우를 고려해 주식 가격을 조정한 가격)|중요하게 사용할 부분
# name|주식명

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832352 entries, 0 to 832351
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date       832352 non-null  object
#  1   open       832352 non-null  int64
#  2   high       832352 non-null  int64
#  3   low        832352 non-null  int64
#  4   close      832352 non-null  int64
#  5   volume     832352 non-null  int64
#  6   adj_close  832352 non-null  int64
#  7   name       832352 non-null  object
# dtypes: int64(6), object(2)
# memory usage: 50.8+ MB

# %%
#용량 줄이는 코드
import numpy as np

def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)

    return df
df = reduce_mem_usage(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832352 entries, 0 to 832351
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date       832352 non-null  object
#  1   open       832352 non-null  int32
#  2   high       832352 non-null  int32
#  3   low        832352 non-null  int32
#  4   close      832352 non-null  int32
#  5   volume     832352 non-null  int64
#  6   adj_close  832352 non-null  int32
#  7   name       832352 non-null  object
# dtypes: int32(5), int64(1), object(2)
# memory usage: 34.9+ MB

# %% [markdown]
# ### 데이터 타입 변경 및 열 추가

# %%
#데이터 타입 변경
df["date"]=pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 832352 entries, 0 to 832351
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   date       832352 non-null  datetime64[ns]
#  1   open       832352 non-null  int32
#  2   high       832352 non-null  int32
#  3   low        832352 non-null  int32
#  4   close      832352 non-null  int32
#  5   volume     832352 non-null  int64
#  6   adj_close  832352 non-null  int32
#  7   name       832352 non-null  object
# dtypes: datetime64[ns](1), int32(5), int64(1), object(1)
# memory usage: 34.9+ MB

# %%
#날짜형 데이터 년/월/일/요일 구분
df["year"]=df["date"].dt.year
df["month"]=df["date"].dt.month
df["day"]=df["date"].dt.day
df["dayofweek"]=df["date"].dt.dayofweek
df
# Out:
#              date   open   high    low  close    volume  adj_close    name  \
# 0      2005-09-29  43517  45553  43466      0     49472      36129  000070
# 1      2005-09-30  45808  47436  45604      0     72960      37515  000070
# 2      2005-10-04  47742  47742  46011      0     25256      37393  000070
# 3      2005-10-05  46927  47131  44841      0     36053      35925  000070
# 4      2005-10-06  44383  44993  43110      0     38066      34987  000070
# ...           ...    ...    ...    ...    ...       ...        ...     ...
# 832347 2021-04-09  10500  10500  10200  10300  19929467      10300  316140
# 832348 2021-04-12  10300  10450  10250  10400   2507164      10400  316140
# 832349 2021-04-13  10450  10450  10300  10350   2085798      10350  316140
# 832350 2021-04-14  10350  10400  10300  10400   1503857      10400  316140
# 832351 2021-04-15  10400  10550  10350  10400   2454194      10400  316140
#
#         year  month  day  dayofweek
# 0       2005      9   29          3
# 1       2005      9   30          4
# 2       2005     10    4          1
# 3       2005     10    5          2
# 4       2005     10    6          3
# ...      ...    ...  ...        ...
# 832347  2021      4    9          4
# 832348  2021      4   12          0
# 832349  2021      4   13          1
# 832350  2021      4   14          2
# 832351  2021      4   15          3
#
# [832352 rows x 12 columns]

# %%
#시가와 종가의 차이
df["differ"] = (df["open"] - df["close"])
df
# Out:
#              date   open   high    low  close    volume  adj_close    name  \
# 0      2005-09-29  43517  45553  43466      0     49472      36129  000070
# 1      2005-09-30  45808  47436  45604      0     72960      37515  000070
# 2      2005-10-04  47742  47742  46011      0     25256      37393  000070
# 3      2005-10-05  46927  47131  44841      0     36053      35925  000070
# 4      2005-10-06  44383  44993  43110      0     38066      34987  000070
# ...           ...    ...    ...    ...    ...       ...        ...     ...
# 832347 2021-04-09  10500  10500  10200  10300  19929467      10300  316140
# 832348 2021-04-12  10300  10450  10250  10400   2507164      10400  316140
# 832349 2021-04-13  10450  10450  10300  10350   2085798      10350  316140
# 832350 2021-04-14  10350  10400  10300  10400   1503857      10400  316140
# 832351 2021-04-15  10400  10550  10350  10400   2454194      10400  316140
#
#         year  month  day  dayofweek  differ
# 0       2005      9   29          3   43517
# 1       2005      9   30          4   45808
# 2       2005     10    4          1   47742
# 3       2005     10    5          2   46927
# 4       2005     10    6          3   44383
# ...      ...    ...  ...        ...     ...
# 832347  2021      4    9          4     200
# 832348  2021      4   12          0    -100
# 832349  2021      4   13          1     100
# 832350  2021      4   14          2     -50
# 832351  2021      4   15          3       0
#
# [832352 rows x 13 columns]

# %%
#최고가와 최저가의 중간값(평균)
df["avg"] = (df["high"] - df["low"])/2
df
# Out:
#              date   open   high    low  close    volume  adj_close    name  \
# 0      2005-09-29  43517  45553  43466      0     49472      36129  000070
# 1      2005-09-30  45808  47436  45604      0     72960      37515  000070
# 2      2005-10-04  47742  47742  46011      0     25256      37393  000070
# 3      2005-10-05  46927  47131  44841      0     36053      35925  000070
# 4      2005-10-06  44383  44993  43110      0     38066      34987  000070
# ...           ...    ...    ...    ...    ...       ...        ...     ...
# 832347 2021-04-09  10500  10500  10200  10300  19929467      10300  316140
# 832348 2021-04-12  10300  10450  10250  10400   2507164      10400  316140
# 832349 2021-04-13  10450  10450  10300  10350   2085798      10350  316140
# 832350 2021-04-14  10350  10400  10300  10400   1503857      10400  316140
# 832351 2021-04-15  10400  10550  10350  10400   2454194      10400  316140
#
#         year  month  day  dayofweek  differ     avg
# 0       2005      9   29          3   43517  1043.5
# 1       2005      9   30          4   45808   916.0
# 2       2005     10    4          1   47742   865.5
# 3       2005     10    5          2   46927  1145.0
# 4       2005     10    6          3   44383   941.5
# ...      ...    ...  ...        ...     ...     ...
# 832347  2021      4    9          4     200   150.0
# 832348  2021      4   12          0    -100   100.0
# 832349  2021      4   13          1     100    75.0
# 832350  2021      4   14          2     -50    50.0
# 832351  2021      4   15          3       0   100.0
#
# [832352 rows x 14 columns]

# %%
#데이터 순서를 보기 편하게 변경
df=df[["name", "adj_close", "open", "high", "low", "close","differ", "avg", "volume", "date", "year", "month", "day", "dayofweek"]]
df
# Out:
#           name  adj_close   open   high    low  close  differ     avg  \
# 0       000070      36129  43517  45553  43466      0   43517  1043.5
# 1       000070      37515  45808  47436  45604      0   45808   916.0
# 2       000070      37393  47742  47742  46011      0   47742   865.5
# 3       000070      35925  46927  47131  44841      0   46927  1145.0
# 4       000070      34987  44383  44993  43110      0   44383   941.5
# ...        ...        ...    ...    ...    ...    ...     ...     ...
# 832347  316140      10300  10500  10500  10200  10300     200   150.0
# 832348  316140      10400  10300  10450  10250  10400    -100   100.0
# 832349  316140      10350  10450  10450  10300  10350     100    75.0
# 832350  316140      10400  10350  10400  10300  10400     -50    50.0
# 832351  316140      10400  10400  10550  10350  10400       0   100.0
#
#           volume       date  year  month  day  dayofweek
# 0          49472 2005-09-29  2005      9   29          3
# 1          72960 2005-09-30  2005      9   30          4
# 2          25256 2005-10-04  2005     10    4          1
# 3          36053 2005-10-05  2005     10    5          2
# 4          38066 2005-10-06  2005     10    6          3
# ...          ...        ...   ...    ...  ...        ...
# 832347  19929467 2021-04-09  2021      4    9          4
# 832348   2507164 2021-04-12  2021      4   12          0
# 832349   2085798 2021-04-13  2021      4   13          1
# 832350   1503857 2021-04-14  2021      4   14          2
# 832351   2454194 2021-04-15  2021      4   15          3
#
# [832352 rows x 14 columns]

# %% [markdown]
# ### 데이터 결측치 확인

# %%
df[df["adj_close"]==0]
# Out:
#           name  adj_close  open  high  low  close  differ  avg  volume  \
# 2960    000070          0     0     0    0      0       0  0.0       0
# 3299    000070          0     0     0    0      0       0  0.0       0
# 6524    000080          0     0     0    0      0       0  0.0       0
# 6861    000080          0     0     0    0      0       0  0.0       0
# 11786   000100          0     0     0    0      0       0  0.0       0
# ...        ...        ...   ...   ...  ...    ...     ...  ...     ...
# 830310  285130          0     0     0    0      0       0  0.0       0
# 830639  285130          0     0     0    0      0       0  0.0       0
# 831114  294870          0     0     0    0      0       0  0.0       0
# 831341  294870          0     0     0    0      0       0  0.0       0
# 831877  316140          0     0     0    0      0       0  0.0       0
#
#              date  year  month  day  dayofweek
# 2960   2017-12-27  2017     12   27          2
# 3299   2019-05-16  2019      5   16          3
# 6524   2017-12-27  2017     12   27          2
# 6861   2019-05-16  2019      5   16          3
# 11786  2017-12-27  2017     12   27          2
# ...           ...   ...    ...  ...        ...
# 830310 2018-01-09  2018      1    9          1
# 830639 2019-05-16  2019      5   16          3
# 831114 2018-06-11  2018      6   11          0
# 831341 2019-05-16  2019      5   16          3
# 831877 2019-05-16  2019      5   16          3
#
# [4097 rows x 14 columns]

# %%
df[df["adj_close"]==0]
# Out:
#           name  adj_close  open  high  low  close  differ  avg  volume  \
# 2960    000070          0     0     0    0      0       0  0.0       0
# 3299    000070          0     0     0    0      0       0  0.0       0
# 6524    000080          0     0     0    0      0       0  0.0       0
# 6861    000080          0     0     0    0      0       0  0.0       0
# 11786   000100          0     0     0    0      0       0  0.0       0
# ...        ...        ...   ...   ...  ...    ...     ...  ...     ...
# 830310  285130          0     0     0    0      0       0  0.0       0
# 830639  285130          0     0     0    0      0       0  0.0       0
# 831114  294870          0     0     0    0      0       0  0.0       0
# 831341  294870          0     0     0    0      0       0  0.0       0
# 831877  316140          0     0     0    0      0       0  0.0       0
#
#              date  year  month  day  dayofweek
# 2960   2017-12-27  2017     12   27          2
# 3299   2019-05-16  2019      5   16          3
# 6524   2017-12-27  2017     12   27          2
# 6861   2019-05-16  2019      5   16          3
# 11786  2017-12-27  2017     12   27          2
# ...           ...   ...    ...  ...        ...
# 830310 2018-01-09  2018      1    9          1
# 830639 2019-05-16  2019      5   16          3
# 831114 2018-06-11  2018      6   11          0
# 831341 2019-05-16  2019      5   16          3
# 831877 2019-05-16  2019      5   16          3
#
# [4097 rows x 14 columns]

# %%
#주가가 0인 데이터는 제거
df_drop=df[df["adj_close"]==0].index
df=df.drop(index=df_drop, axis=0)
df=df.reset_index(drop=True)
df
# Out:
#           name  adj_close   open   high    low  close  differ     avg  \
# 0       000070      36129  43517  45553  43466      0   43517  1043.5
# 1       000070      37515  45808  47436  45604      0   45808   916.0
# 2       000070      37393  47742  47742  46011      0   47742   865.5
# 3       000070      35925  46927  47131  44841      0   46927  1145.0
# 4       000070      34987  44383  44993  43110      0   44383   941.5
# ...        ...        ...    ...    ...    ...    ...     ...     ...
# 828250  316140      10300  10500  10500  10200  10300     200   150.0
# 828251  316140      10400  10300  10450  10250  10400    -100   100.0
# 828252  316140      10350  10450  10450  10300  10350     100    75.0
# 828253  316140      10400  10350  10400  10300  10400     -50    50.0
# 828254  316140      10400  10400  10550  10350  10400       0   100.0
#
#           volume       date  year  month  day  dayofweek
# 0          49472 2005-09-29  2005      9   29          3
# 1          72960 2005-09-30  2005      9   30          4
# 2          25256 2005-10-04  2005     10    4          1
# 3          36053 2005-10-05  2005     10    5          2
# 4          38066 2005-10-06  2005     10    6          3
# ...          ...        ...   ...    ...  ...        ...
# 828250  19929467 2021-04-09  2021      4    9          4
# 828251   2507164 2021-04-12  2021      4   12          0
# 828252   2085798 2021-04-13  2021      4   13          1
# 828253   1503857 2021-04-14  2021      4   14          2
# 828254   2454194 2021-04-15  2021      4   15          3
#
# [828255 rows x 14 columns]

# %%
df[df["open"]==0]
# Out:
#           name  adj_close  open    high     low   close  differ     avg  \
# 173599  003550      76100     0   77000   75600   76100  -76100   700.0
# 677735  051910     378000     0  378500  371000  378000 -378000  3750.0
# 726106  071840      48150     0   50500   48000   48150  -48150  1250.0
# 787342  115390      19600     0   19600   19000   19600  -19600   300.0
# 817641  207940     379500     0  382000  377500  379500 -379500  2250.0
#
#         volume       date  year  month  day  dayofweek
# 173599  191761 2019-02-13  2019      2   13          2
# 677735  238937 2019-02-13  2019      2   13          2
# 726106  187761 2019-02-13  2019      2   13          2
# 787342  136366 2019-02-13  2019      2   13          2
# 817641   81128 2019-02-13  2019      2   13          2

# %%
#시가가 0인 데이터 제거
df_drop=df[df["open"]==0].index
df=df.drop(index=df_drop, axis=0)
df=df.reset_index(drop=True)
df
# Out:
#           name  adj_close   open   high    low  close  differ     avg  \
# 0       000070      36129  43517  45553  43466      0   43517  1043.5
# 1       000070      37515  45808  47436  45604      0   45808   916.0
# 2       000070      37393  47742  47742  46011      0   47742   865.5
# 3       000070      35925  46927  47131  44841      0   46927  1145.0
# 4       000070      34987  44383  44993  43110      0   44383   941.5
# ...        ...        ...    ...    ...    ...    ...     ...     ...
# 828245  316140      10300  10500  10500  10200  10300     200   150.0
# 828246  316140      10400  10300  10450  10250  10400    -100   100.0
# 828247  316140      10350  10450  10450  10300  10350     100    75.0
# 828248  316140      10400  10350  10400  10300  10400     -50    50.0
# 828249  316140      10400  10400  10550  10350  10400       0   100.0
#
#           volume       date  year  month  day  dayofweek
# 0          49472 2005-09-29  2005      9   29          3
# 1          72960 2005-09-30  2005      9   30          4
# 2          25256 2005-10-04  2005     10    4          1
# 3          36053 2005-10-05  2005     10    5          2
# 4          38066 2005-10-06  2005     10    6          3
# ...          ...        ...   ...    ...  ...        ...
# 828245  19929467 2021-04-09  2021      4    9          4
# 828246   2507164 2021-04-12  2021      4   12          0
# 828247   2085798 2021-04-13  2021      4   13          1
# 828248   1503857 2021-04-14  2021      4   14          2
# 828249   2454194 2021-04-15  2021      4   15          3
#
# [828250 rows x 14 columns]

# %%
df[df["high"]==0]
# Out:
# Empty DataFrame
# Columns: [name, adj_close, open, high, low, close, differ, avg, volume, date, year, month, day, dayofweek]
# Index: []

# %%
df[df["low"]==0]
# Out:
# Empty DataFrame
# Columns: [name, adj_close, open, high, low, close, differ, avg, volume, date, year, month, day, dayofweek]
# Index: []

# %%
df[df["close"]==0]
# Out:
#           name  adj_close    open    high     low  close  differ     avg  \
# 0       000070      36129   43517   45553   43466      0   43517  1043.5
# 1       000070      37515   45808   47436   45604      0   45808   916.0
# 2       000070      37393   47742   47742   46011      0   47742   865.5
# 3       000070      35925   46927   47131   44841      0   46927  1145.0
# 4       000070      34987   44383   44993   43110      0   44383   941.5
# ...        ...        ...     ...     ...     ...    ...     ...     ...
# 376013  009540     107069  107069  107069  107069      0  107069     0.0
# 376014  009540     107069  107069  107069  107069      0  107069     0.0
# 376015  009540     107069  107069  107069  107069      0  107069     0.0
# 376016  009540     107069  107069  107069  107069      0  107069     0.0
# 376017  009540     107069  107069  107069  107069      0  107069     0.0
#
#         volume       date  year  month  day  dayofweek
# 0        49472 2005-09-29  2005      9   29          3
# 1        72960 2005-09-30  2005      9   30          4
# 2        25256 2005-10-04  2005     10    4          1
# 3        36053 2005-10-05  2005     10    5          2
# 4        38066 2005-10-06  2005     10    6          3
# ...        ...        ...   ...    ...  ...        ...
# 376013       0 2017-04-27  2017      4   27          3
# 376014       0 2017-04-28  2017      4   28          4
# 376015       0 2017-05-02  2017      5    2          1
# 376016       0 2017-05-04  2017      5    4          3
# 376017       0 2017-05-08  2017      5    8          0
#
# [20939 rows x 14 columns]

# %%
#종가가 0인 데이터 제거
df_drop=df[df["close"]==0].index
df=df.drop(index=df_drop, axis=0)
df=df.reset_index(drop=True)
df
# Out:
#           name  adj_close   open   high    low  close  differ     avg  \
# 0       000070      74031  84000  84000  79000  82300    1700  2500.0
# 1       000070      72322  81000  82000  72900  80400     600  4550.0
# 2       000070      75381  80500  85800  78300  83800   -3300  3750.0
# 3       000070      71063  83000  83800  78600  79000    4000  2600.0
# 4       000070      68184  77500  77500  75200  75800    1700  1150.0
# ...        ...        ...    ...    ...    ...    ...     ...     ...
# 807306  316140      10300  10500  10500  10200  10300     200   150.0
# 807307  316140      10400  10300  10450  10250  10400    -100   100.0
# 807308  316140      10350  10450  10450  10300  10350     100    75.0
# 807309  316140      10400  10350  10400  10300  10400     -50    50.0
# 807310  316140      10400  10400  10550  10350  10400       0   100.0
#
#           volume       date  year  month  day  dayofweek
# 0          71250 2011-12-05  2011     12    5          0
# 1          75973 2011-12-06  2011     12    6          1
# 2          70873 2011-12-07  2011     12    7          2
# 3          77794 2011-12-08  2011     12    8          3
# 4          54451 2011-12-09  2011     12    9          4
# ...          ...        ...   ...    ...  ...        ...
# 807306  19929467 2021-04-09  2021      4    9          4
# 807307   2507164 2021-04-12  2021      4   12          0
# 807308   2085798 2021-04-13  2021      4   13          1
# 807309   1503857 2021-04-14  2021      4   14          2
# 807310   2454194 2021-04-15  2021      4   15          3
#
# [807311 rows x 14 columns]

# %%
#데이터 저장
df.to_csv("Korea_Stocks_Kospi.csv")
